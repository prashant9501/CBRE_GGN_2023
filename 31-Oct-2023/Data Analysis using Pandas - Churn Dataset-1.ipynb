# %%
import pandas as pd

# %%
pwd  # print the working directory ... this is the dir where this vurrent jupyter notebook is present.
# Out:
# 'C:\\Users\\Prashant\\Downloads\\AV\\SBSA 2023'

# %%
df = pd.read_csv("churn_prediction.csv")
df
# Out:
#        customer_id  vintage  age  gender  dependents     occupation    city  \
# 0                1     2401   66    Male         0.0  self_employed   187.0
# 1                2     2648   35    Male         0.0  self_employed     NaN
# 2                4     2494   31    Male         0.0       salaried   146.0
# 3                5     2629   90     NaN         NaN  self_employed  1020.0
# 4                6     1879   42    Male         2.0  self_employed  1494.0
# ...            ...      ...  ...     ...         ...            ...     ...
# 15925        16993     2500   64  Female         0.0  self_employed   409.0
# 15926        16994     2470   44    Male         0.0       salaried  1020.0
# 15927        16995     2537   34  Female         1.0  self_employed   557.0
# 15928        16996     2287   56  Female         0.0  self_employed  1540.0
# 15929        16997     2656   70    Male         0.0  self_employed  1096.0
#
# ...

# %%
df['customer_id'].value_counts()
# all the value_counts of the customer_id col has a freq. of 1
# impleis that each value occurs just once !
# Out:
# 1        1
# 11350    1
# 11337    1
# 11338    1
# 11339    1
#         ..
# 5659     1
# 5660     1
# 5661     1
# 5662     1
# 16997    1
# Name: customer_id, Length: 15930, dtype: int64

# %%
df['customer_id'].nunique() == len(df['customer_id'])
# Out:
# True

# %%
len(set(df['customer_id'])) == len(df['customer_id'])  
# if the no. of unique values in the customer_id col is equal to the length of the customer_id col
# then it means that every value of the customer_id col is unique
# Out:
# True

# %%
# fetch the values for occupation col >> Series

# %%
# fetch the values for occupation col as Pandas DF

# %%
# fetch the values for gender, occupation & age col

# %%
import numpy as np
np.random.seed(42)
arr = np.round(100*np.random.randn(4,5))
arr_df = pd.DataFrame(arr, index=["India", "Nigeria", "SA", "Zambia"], columns='A B C D E'.split())
arr_df
# Out:
#             A      B     C      D      E
# India    50.0  -14.0  65.0  152.0  -23.0
# Nigeria -23.0  158.0  77.0  -47.0   54.0
# SA      -46.0  -47.0  24.0 -191.0 -172.0
# Zambia  -56.0 -101.0  31.0  -91.0 -141.0

# %%
# how to fetch a single row ?
arr_df.loc['Nigeria']  # "locating" a row by its LABEL, & fetch the vlaues
# Out:
# A    -23.0
# B    158.0
# C     77.0
# D    -47.0
# E     54.0
# Name: Nigeria, dtype: float64

# %%
type(arr_df.loc['Nigeria'])
# Out:
# pandas.core.series.Series

# %%
arr_df
# Out:
#             A      B     C      D      E
# India    50.0  -14.0  65.0  152.0  -23.0
# Nigeria -23.0  158.0  77.0  -47.0   54.0
# SA      -46.0  -47.0  24.0 -191.0 -172.0
# Zambia  -56.0 -101.0  31.0  -91.0 -141.0

# %%
arr_df.iloc[1] # "locating" a row by its INDEX, & fetch the vlaues
# the index of Nigeria is 1
# Out:
# A    -23.0
# B    158.0
# C     77.0
# D    -47.0
# E     54.0
# Name: Nigeria, dtype: float64

# %%
arr_df.iloc[-1]
# Out:
# A    -56.0
# B   -101.0
# C     31.0
# D    -91.0
# E   -141.0
# Name: Zambia, dtype: float64

# %%
np.random.seed(42)
arr = np.round(100*np.random.randn(4,5))
arr_df = pd.DataFrame(arr, index=["SA", "Nigeria", "SA", "Zambia"], columns='A B C D E'.split())
arr_df
# Out:
#             A      B     C      D      E
# SA       50.0  -14.0  65.0  152.0  -23.0
# Nigeria -23.0  158.0  77.0  -47.0   54.0
# SA      -46.0  -47.0  24.0 -191.0 -172.0
# Zambia  -56.0 -101.0  31.0  -91.0 -141.0

# %%
arr_df.loc['SA']
# Out:
#        A     B     C      D      E
# SA  50.0 -14.0  65.0  152.0  -23.0
# SA -46.0 -47.0  24.0 -191.0 -172.0

# %%
arr_df.iloc[0]  # fetching the 1st row
# Out:
# A     50.0
# B    -14.0
# C     65.0
# D    152.0
# E    -23.0
# Name: SA, dtype: float64

# %%
arr_df.iloc[0:3]  # fetch the 1st 3 rows
# Out:
#             A      B     C      D      E
# SA       50.0  -14.0  65.0  152.0  -23.0
# Nigeria -23.0  158.0   inf  -47.0   54.0
# SA      -46.0  -47.0  24.0 -191.0 -172.0

# %%
arr_df
# Out:
#             A      B     C      D      E
# SA       50.0  -14.0  65.0  152.0  -23.0
# Nigeria -23.0  158.0  77.0  -47.0   54.0
# SA      -46.0  -47.0  24.0 -191.0 -172.0
# Zambia  -56.0 -101.0  31.0  -91.0 -141.0

# %%
arr[1,2]  # indexing on a numpy array
# Out:
# 77.0

# %%
arr_df.iloc[1, 2]   # indexing on a Pandas DF
# Out:
# 77.0

# %%
arr_df.iloc[:, 2]  # all the rows of the 3rd col
# Out:
# SA         65.0
# Nigeria    77.0
# SA         24.0
# Zambia     31.0
# Name: C, dtype: float64

# %%
arr_df.iloc[-1, :]  # last row, all the columns
# Out:
# A    -56.0
# B   -101.0
# C     31.0
# D    -91.0
# E   -141.0
# Name: Zambia, dtype: float64

# %%
arr_df
# Out:
#             A      B     C      D      E
# SA       50.0  -14.0  65.0  152.0  -23.0
# Nigeria -23.0  158.0  77.0  -47.0   54.0
# SA      -46.0  -47.0  24.0 -191.0 -172.0
# Zambia  -56.0 -101.0  31.0  -91.0 -141.0

# %%
arr_df.iloc[2:, 2:]
# Out:
#            C      D      E
# SA      24.0 -191.0 -172.0
# Zambia  31.0  -91.0 -141.0

# %%
arr_df.iloc[1, 2] = np.inf
arr_df
# Out:
#             A      B     C      D      E
# SA       50.0  -14.0  65.0  152.0  -23.0
# Nigeria -23.0  158.0   inf  -47.0   54.0
# SA      -46.0  -47.0  24.0 -191.0 -172.0
# Zambia  -56.0 -101.0  31.0  -91.0 -141.0

# %%
arr_df.iloc[0, :] = 100
arr_df
# Out:
#              A      B      C      D      E
# SA       100.0  100.0  100.0  100.0  100.0
# Nigeria  -23.0  158.0    inf  -47.0   54.0
# SA       -46.0  -47.0   24.0 -191.0 -172.0
# Zambia   -56.0 -101.0   31.0  -91.0 -141.0

# %%
arr_df.iloc[2, :] = [10, 20, 30, 40, 50]
arr_df
# Out:
#              A      B      C      D      E
# SA       100.0  100.0  100.0  100.0  100.0
# Nigeria  -23.0  158.0    inf  -47.0   54.0
# SA        10.0   20.0   30.0   40.0   50.0
# Zambia   -56.0 -101.0   31.0  -91.0 -141.0

# %%
df
# Out:
#        customer_id  vintage  age  gender  dependents     occupation    city  \
# 0                1     2401   66    Male         0.0  self_employed   187.0
# 1                2     2648   35    Male         0.0  self_employed     NaN
# 2                4     2494   31    Male         0.0       salaried   146.0
# 3                5     2629   90     NaN         NaN  self_employed  1020.0
# 4                6     1879   42    Male         2.0  self_employed  1494.0
# ...            ...      ...  ...     ...         ...            ...     ...
# 15925        16993     2500   64  Female         0.0  self_employed   409.0
# 15926        16994     2470   44    Male         0.0       salaried  1020.0
# 15927        16995     2537   34  Female         1.0  self_employed   557.0
# 15928        16996     2287   56  Female         0.0  self_employed  1540.0
# 15929        16997     2656   70    Male         0.0  self_employed  1096.0
#
# ...

# %% [markdown]
# ## Conditional Indexing

# %%
# Fetch all the records for Males
df['gender']=='Male'
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 15925    False
# 15926     True
# 15927    False
# 15928    False
# 15929     True
# Name: gender, Length: 15930, dtype: bool

# %%
sum(df['gender']=='Male')   # total number of males in the dataset
# Out:
# 9308

# %%
df[df['gender']=='Male']
# Out:
#        customer_id  vintage  age gender  dependents     occupation    city  \
# 0                1     2401   66   Male         0.0  self_employed   187.0
# 1                2     2648   35   Male         0.0  self_employed     NaN
# 2                4     2494   31   Male         0.0       salaried   146.0
# 4                6     1879   42   Male         2.0  self_employed  1494.0
# 6                8     2348   72   Male         0.0        retired  1020.0
# ...            ...      ...  ...    ...         ...            ...     ...
# 15920        16988     2536   54   Male         1.0  self_employed   318.0
# 15922        16990     2288   32   Male         0.0       salaried   751.0
# 15924        16992     2175   40   Male         0.0       salaried   698.0
# 15926        16994     2470   44   Male         0.0       salaried  1020.0
# 15929        16997     2656   70   Male         0.0  self_employed  1096.0
#
#        customer_nw_category  branch_code  current_balance  ...  \
# ...

# %%
df[df['gender']=='Male'].shape[0]
# Out:
# 9308

# %%
len(df[df['gender']=='Male'])
# Out:
# 9308

# %%
df['gender'].unique() # unique values in the col
# Out:
# array(['Male', nan, 'Female'], dtype=object)

# %%
df['gender'].nunique()   # there only 2 unique values (male & female), excl. NAns
# Out:
# 2

# %%
df['gender'].value_counts()
# Out:
# Male      9308
# Female    6334
# Name: gender, dtype: int64

# %%
df['gender'].value_counts(dropna=False)
# Out:
# Male      9308
# Female    6334
# NaN        288
# Name: gender, dtype: int64

# %%
df['gender'].value_counts()/len(df)
# Out:
# Male      0.584306
# Female    0.397615
# Name: gender, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15930 entries, 0 to 15929
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   customer_id                     15930 non-null  int64
#  1   vintage                         15930 non-null  int64
#  2   age                             15930 non-null  int64
#  3   gender                          15642 non-null  object
#  4   dependents                      14582 non-null  float64
#  5   occupation                      15883 non-null  object
#  6   city                            15470 non-null  float64
#  7   customer_nw_category            15930 non-null  int64
#  8   branch_code                     15930 non-null  int64
#  9   current_balance                 15930 non-null  float64
#  10  previous_month_end_balance      15930 non-null  float64
#  11  average_monthly_balance_prevQ   15930 non-null  float64
# ...

# %%
9308/15642
# Out:
# 0.5950645697481141

# %%
df['gender'].value_counts(normalize=True, dropna=False)
# Out:
# Male      0.584306
# Female    0.397615
# NaN       0.018079
# Name: gender, dtype: float64

# %%
df['gender'].value_counts(normalize=True)
# Out:
# Male      0.595065
# Female    0.404935
# Name: gender, dtype: float64

# %%
df['occupation'].unique()
# Out:
# array(['self_employed', 'salaried', 'retired', 'student', nan, 'company'],
#       dtype=object)

# %%
# how many self_employed customers are present in your dataset ?
sum(df['occupation'] == 'self_employed')
# Out:
# 9814

# %%
# how many female self_employed customers are present in your dataset ?
(df['gender']=='Female') & (df['occupation'] == 'self_employed')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15925     True
# 15926    False
# 15927     True
# 15928     True
# 15929    False
# Length: 15930, dtype: bool

# %%
sum((df['gender']=='Female') & (df['occupation'] == 'self_employed'))
# Out:
# 4510

# %%
df[(df['gender']=='Female') & (df['occupation'] == 'self_employed')]
# Out:
#        customer_id  vintage  age  gender  dependents     occupation    city  \
# 5                7     2223   42  Female         0.0  self_employed  1096.0
# 14              16     2217   48  Female         0.0  self_employed   665.0
# 15              17     1816   51  Female         0.0  self_employed  1232.0
# 17              20     2431   52  Female         0.0  self_employed  1096.0
# 18              21     2402   47  Female         1.0  self_employed   146.0
# ...            ...      ...  ...     ...         ...            ...     ...
# 15921        16989     2659   48  Female         0.0  self_employed   646.0
# 15923        16991     2683   45  Female         NaN  self_employed    78.0
# 15925        16993     2500   64  Female         0.0  self_employed   409.0
# 15927        16995     2537   34  Female         1.0  self_employed   557.0
# 15928        16996     2287   56  Female         0.0  self_employed  1540.0
#
# ...

# %%
# How many customers have current_month_balance OR previous_month_balance greater than 15000 ?
df[(df['current_month_balance'] > 15000) | (df['previous_month_balance'] > 15000)]
# Out:
#        customer_id  vintage  age  gender  dependents     occupation    city  \
# 5                7     2223   42  Female         0.0  self_employed  1096.0
# 26              29     2178   36    Male         2.0  self_employed  1563.0
# 30              33     2531   66    Male         0.0        retired  1096.0
# 49              52     2550   30  Female         0.0  self_employed   409.0
# 53              57     2560   34    Male         0.0  self_employed   146.0
# ...            ...      ...  ...     ...         ...            ...     ...
# 15877        16942     2581   60    Male         0.0       salaried  1096.0
# 15879        16944     2356   54    Male         2.0       salaried   409.0
# 15918        16984     2094   48  Female         0.0  self_employed  1439.0
# 15920        16988     2536   54    Male         1.0  self_employed   318.0
# 15923        16991     2683   45  Female         NaN  self_employed    78.0
#
# ...

# %%
sum((df['current_month_balance'] > 15000) | (df['previous_month_balance'] > 15000) )
# Out:
# 1554

# %%
len(set(df[(df['current_month_balance'] > 15000) | (df['previous_month_balance'] > 15000)]['customer_id']))
# Out:
# 1554

# %%
# what is the average age of the customers
df['age'].mean()
# Out:
# 48.17457627118644

# %%
# what is the average previous_month_balance of the customers
df['previous_month_balance'].mean()
# Out:
# 7438.764829556121

# %%
# what is the min and max current_month_balance of the customers
df['current_month_balance'].min()
# Out:
# -3374.18

# %%
df['current_month_balance'].max()
# Out:
# 5778184.77

# %%
# Which customer_id has the highest current_month_balance **, 
df[df['current_month_balance'] == df['current_month_balance'].max()]
# Out:
#       customer_id  vintage  age gender  dependents     occupation   city  \
# 9908        10575     2523   90    NaN         NaN  self_employed  243.0
#
#       customer_nw_category  branch_code  current_balance  ...  \
# 9908                     2         2542       5905904.03  ...
#
#       average_monthly_balance_prevQ  average_monthly_balance_prevQ2  \
# 9908                     5700289.57                       5010170.1
#
#       current_month_credit  previous_month_credit  current_month_debit  \
# 9908               5232.34                1452.87             17327.27
#
#       previous_month_debit  current_month_balance  previous_month_balance  \
# 9908               17248.3             5778184.77               5720144.5
#
#       last_transaction churn
# 9908        2019-12-13   0.0
#
# [1 rows x 21 columns]

# %%
df[df['current_month_balance'] == df['current_month_balance'].max()] ['customer_id']
# Out:
# 9908    10575
# Name: customer_id, dtype: int64

# %%
df[df['current_month_balance'] == df['current_month_balance'].max()] ['customer_id'].values[0]
# Out:
# 10575

# %%
df[df['current_month_balance'] == df['current_month_balance'].max()] ['customer_id'].iloc[0]
# Out:
# 10575

# %%
df['current_month_balance'].argmax()  # location/index of the max value
# Out:
# 9908

# %%
df.iloc[df['current_month_balance'].argmax()] ['customer_id']
# Out:
# 10575

# %%
df.iloc[df['current_month_balance'].argmax()] [['customer_id','age', 'gender']]
# Out:
# customer_id    10575
# age               90
# gender           NaN
# Name: 9908, dtype: object

# %%
# and what is his/her age & gender
df[df['current_month_balance'] == df['current_month_balance'].max()] [['customer_id','age', 'gender']]
# Out:
#       customer_id  age gender
# 9908        10575   90    NaN

# %%
df.set_index('customer_id', drop=True, inplace=True)

# %%
df
# Out:
#              vintage  age  gender  dependents     occupation    city  \
# customer_id
# 1               2401   66    Male         0.0  self_employed   187.0
# 2               2648   35    Male         0.0  self_employed     NaN
# 4               2494   31    Male         0.0       salaried   146.0
# 5               2629   90     NaN         NaN  self_employed  1020.0
# 6               1879   42    Male         2.0  self_employed  1494.0
# ...              ...  ...     ...         ...            ...     ...
# 16993           2500   64  Female         0.0  self_employed   409.0
# 16994           2470   44    Male         0.0       salaried  1020.0
# 16995           2537   34  Female         1.0  self_employed   557.0
# 16996           2287   56  Female         0.0  self_employed  1540.0
# 16997           2656   70    Male         0.0  self_employed  1096.0
#
#              customer_nw_category  branch_code  current_balance  \
# customer_id
# ...
