# %% [markdown]
# # Step 1: Load the Dataset

# %%
import pandas as pd

df = pd.read_pickle("churn_prediction_v3.pkl")

# %%
df.head()
# Out:
#    vintage  age gender  dependents     occupation    city  \
# 0     2401   66   Male           0  self_employed    2002
# 1     2648   35   Male           0  self_employed  100000
# 2     2494   31   Male           0       salaried     146
# 3     2629   90   Male           1  self_employed    1020
# 4     1879   42   Male           2  self_employed    1494
#
#   customer_nw_category branch_code  current_balance  \
# 0                    2         755          1458.71
# 1                    2        3214          5390.37
# 2                    2          41          3913.16
# 3                    2         582          2291.91
# 4                    3         388           927.72
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# 0                     1458.71                        1458.71
# 1                     8704.66                        7799.26
# 2                     5815.29                        4910.17
# 3                     2291.91                        2084.54
# 4                     1401.72                        1643.31
#
#    average_monthly_balance_prevQ2  current_month_credit  \
# 0                         1449.07                  0.20
# 1                        12419.41                  0.56
# 2                         2815.94                  0.61
# 3                         1006.54                  0.47
# 4                         1871.12                  0.33
#
#    previous_month_credit  current_month_debit  previous_month_debit  \
# 0                   0.20                 0.20                  0.20
# 1                   0.56              5486.27                100.56
# 2                   0.61              6046.73                259.23
# 3                   0.47                 0.47               2143.33
# 4                 714.61               588.62               1538.06
#
#    current_month_balance  previous_month_balance churn
# 0                1458.71                 1458.71   0.0
# 1                6496.78                 8787.61   0.0
# 2                5006.28                 5070.14   0.0
# 3                2291.91                 1669.79   1.0
# 4                1157.15                 1677.16   1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15929 entries, 0 to 15928
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   vintage                         15929 non-null  int64
#  1   age                             15929 non-null  int64
#  2   gender                          15929 non-null  category
#  3   dependents                      15929 non-null  int64
#  4   occupation                      15929 non-null  category
#  5   city                            15929 non-null  category
#  6   customer_nw_category            15929 non-null  category
#  7   branch_code                     15929 non-null  category
#  8   current_balance                 15929 non-null  float64
#  9   previous_month_end_balance      15929 non-null  float64
#  10  average_monthly_balance_prevQ   15929 non-null  float64
#  11  average_monthly_balance_prevQ2  15929 non-null  float64
#  12  current_month_credit            15929 non-null  float64
#  13  previous_month_credit           15929 non-null  float64
#  14  current_month_debit             15929 non-null  float64
#  15  previous_month_debit            15929 non-null  float64
#  16  current_month_balance           15929 non-null  float64
#  17  previous_month_balance          15929 non-null  float64
#  18  churn                           15929 non-null  category
# dtypes: category(6), float64(10), int64(3)
# memory usage: 1.7 MB

# %%
# average_monthly_balance_prevQ >>> Target varaible

# %%
# Steps for Model Building
# 0. Convert your Business problem into a Data Problem
# 1. Load the dataset
# 2. Exploratory Data Analysis:
# 3. Bare minimum data cleaning (e.g. missing value imputation) & 
# preprocessing (e.g. Encoding the cat. variables)

# 4. Create Baseline models

# 5. Data Polishing/Refinement: e.g. outlier treatment, scaling the num. features,
# Feature engineering, feature selection, feature transformation, etc.

# ===> Data is FInalized!!
# 6. Compare and Select the best model(s) for "tuning" 

# 7. Hyper-parameter tuning / Model Refinement

# 8. Re-train you final model on the entire data, one last time!

# 9. Save the model (pickelize)

# 10. Share/Deploy the model

# y = f(X)

# Model = Algo(Data)

# %% [markdown]
# # Step 3: Data Cleaning & Basic PRe-processing

# %%
X = df.drop('average_monthly_balance_prevQ', axis=1)  # Features matrix
y = df['average_monthly_balance_prevQ']   # Target variable for Regression

# %%
X.shape, y.shape
# Out:
# ((15929, 18), (15929,))

# %%
pd.get_dummies(X['occupation'], drop_first=True)   # OHE the occupation
# Out:
#        retired  salaried  self_employed  student
# 0            0         0              1        0
# 1            0         0              1        0
# 2            0         1              0        0
# 3            0         0              1        0
# 4            0         0              1        0
# ...        ...       ...            ...      ...
# 15924        0         1              0        0
# 15925        0         0              1        0
# 15926        0         1              0        0
# 15927        0         0              1        0
# 15928        0         0              1        0
#
# [15929 rows x 4 columns]

# %%
categorical_cols = df.dtypes[df.dtypes == 'category'].index  # identifying the categorical variable
categorical_cols
# Out:
# Index(['gender', 'occupation', 'city', 'customer_nw_category', 'branch_code',
#        'churn'],
#       dtype='object')

# %%
for col in categorical_cols:  # list the number of unique values in these cat. columns
    print(col, ":", X[col].nunique())
# Out:
# gender : 2
# occupation : 5
# city : 30
# customer_nw_category : 3
# branch_code : 2806
# churn : 2

# %%
X.drop( 'branch_code', axis=1, inplace=True)  # Dropping the columns, as it has just too many unique values

# %%
X['gender'] = X['gender'].map({'Male':0, 'Female':1})  # Label Encoding the gender col. This can also be One-hot encoded

# %%
nominal_cols = ['occupation', 'city', 'customer_nw_category'] # Selecting out the columns for OHE

# %%
X_new = pd.get_dummies(X, columns=nominal_cols) # One-Hot encoding the Nominal columns

# %%
X_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15929 entries, 0 to 15928
# Data columns (total 52 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   vintage                         15929 non-null  int64
#  1   age                             15929 non-null  int64
#  2   gender                          15929 non-null  category
#  3   dependents                      15929 non-null  int64
#  4   current_balance                 15929 non-null  float64
#  5   previous_month_end_balance      15929 non-null  float64
#  6   average_monthly_balance_prevQ2  15929 non-null  float64
#  7   current_month_credit            15929 non-null  float64
#  8   previous_month_credit           15929 non-null  float64
#  9   current_month_debit             15929 non-null  float64
#  10  previous_month_debit            15929 non-null  float64
#  11  current_month_balance           15929 non-null  float64
#  12  previous_month_balance          15929 non-null  float64
#  13  churn                           15929 non-null  category
#  14  occupation_company              15929 non-null  uint8
#  15  occupation_retired              15929 non-null  uint8
#  16  occupation_salaried             15929 non-null  uint8
#  17  occupation_self_employed        15929 non-null  uint8
#  18  occupation_student              15929 non-null  uint8
#  19  city_15                         15929 non-null  uint8
#  20  city_61                         15929 non-null  uint8
#  21  city_146                        15929 non-null  uint8
#  22  city_318                        15929 non-null  uint8
#  23  city_334                        15929 non-null  uint8
#  24  city_409                        15929 non-null  uint8
#  25  city_491                        15929 non-null  uint8
#  26  city_531                        15929 non-null  uint8
#  27  city_575                        15929 non-null  uint8
#  28  city_623                        15929 non-null  uint8
#  29  city_630                        15929 non-null  uint8
#  30  city_649                        15929 non-null  uint8
#  31  city_656                        15929 non-null  uint8
#  32  city_834                        15929 non-null  uint8
#  33  city_904                        15929 non-null  uint8
#  34  city_905                        15929 non-null  uint8
#  35  city_1020                       15929 non-null  uint8
#  36  city_1084                       15929 non-null  uint8
#  37  city_1096                       15929 non-null  uint8
#  38  city_1111                       15929 non-null  uint8
#  39  city_1232                       15929 non-null  uint8
#  40  city_1494                       15929 non-null  uint8
#  41  city_1525                       15929 non-null  uint8
#  42  city_1589                       15929 non-null  uint8
#  43  city_2001                       15929 non-null  uint8
#  44  city_2002                       15929 non-null  uint8
#  45  city_2012                       15929 non-null  uint8
#  46  city_2013                       15929 non-null  uint8
#  47  city_2014                       15929 non-null  uint8
#  48  city_100000                     15929 non-null  uint8
#  49  customer_nw_category_1          15929 non-null  uint8
#  50  customer_nw_category_2          15929 non-null  uint8
#  51  customer_nw_category_3          15929 non-null  uint8
# dtypes: category(2), float64(9), int64(3), uint8(38)
# memory usage: 2.1 MB

# %% [markdown]
# ## Step 4: Create Baseline Model

# %%
# Split your data into training and validation sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((12743, 52), (3186, 52))

# %%
# All the ML algorithms are referred as "estimators" in the sklearn package...

# and all thse estimators are actually Python "Classes" .... they will have attributes & methods
# Attributes stores some properties/values
# Methods >> functions which will used to "operate" on the data 
# Since all the estimators are Classes... they have to be instantiated, before they can be used.

# %%
X_train
# Out:
#        vintage  age gender  dependents  current_balance  \
# 6682      2110   50      1           0           987.17
# 1665      2617   62      0           1         10579.41
# 13644     2531   62      0           2          1598.32
# 7142      2610   64      1           2          1890.72
# 2582      2544   27      0           0          9223.24
# ...        ...  ...    ...         ...              ...
# 13418     2574   69      0           3         22548.28
# 5390      2561   52      0           1            96.57
# 860       2366   62      0           0          3170.19
# 15795     2657   63      1           0          4127.81
# 7270      2458   51      1           0          6957.94
#
#        previous_month_end_balance  average_monthly_balance_prevQ2  \
# 6682                       487.17                         1984.86
# 1665                      8357.16                         1632.61
# 13644                     2108.68                         1995.06
# 7142                      1754.15                         1581.80
# 2582                      9223.24                        14710.91
# ...                           ...                             ...
# 13418                    21727.52                        37843.84
# 5390                       854.81                         3567.15
# 860                       3170.19                         2828.30
# 15795                     3494.05                         2560.00
# 7270                      9017.71                         3512.82
#
#        current_month_credit  previous_month_credit  current_month_debit  ...  \
# 6682                 500.13                 428.70                 0.13  ...
# 1665                2244.06                7572.83                21.81  ...
# 13644                  0.60                5714.89              1510.74  ...
# 7142                 142.89                   0.03               292.03  ...
# 2582                   0.34               37478.57                 0.34  ...
# ...                     ...                    ...                  ...  ...
# 13418               1057.12                 544.53               554.41  ...
# 5390                   0.21                   0.21             12282.29  ...
# 860                    0.53                   0.53                 0.53  ...
# 15795               1702.10                  49.79              1429.23  ...
# 7270                2484.04                 120.56              6108.33  ...
#
#        city_1589  city_2001  city_2002 city_2012  city_2013  city_2014  \
# 6682           0          0          0         0          0          0
# 1665           0          0          0         0          0          0
# 13644          0          1          0         0          0          0
# 7142           0          0          0         0          0          0
# 2582           0          0          0         0          0          1
# ...          ...        ...        ...       ...        ...        ...
# 13418          0          0          0         0          0          1
# 5390           0          0          0         0          0          0
# 860            0          0          1         0          0          0
# 15795          0          0          0         0          0          1
# 7270           0          0          0         0          0          0
#
#        city_100000  customer_nw_category_1  customer_nw_category_2  \
# 6682             0                       1                       0
# 1665             0                       0                       0
# 13644            0                       0                       1
# 7142             0                       0                       1
# 2582             0                       0                       1
# ...            ...                     ...                     ...
# 13418            0                       0                       1
# 5390             0                       1                       0
# 860              0                       0                       0
# 15795            0                       0                       1
# 7270             0                       1                       0
#
#        customer_nw_category_3
# 6682                        0
# 1665                        1
# 13644                       0
# 7142                        0
# 2582                        0
# ...                       ...
# 13418                       0
# 5390                        0
# 860                         1
# 15795                       0
# 7270                        0
#
# [12743 rows x 52 columns]

# %%
from sklearn.linear_model import LinearRegression

LR = LinearRegression()  # "untrained" model
LR.fit(X_train, y_train)  # model is trained now  >>> fitting means model training here.
# Always fir your model on the training set
# Out:
# LinearRegression()

# %%
LR.predict(X_test)   # predictions of the model on the test set
# Out:
# array([3058.77170518, 4649.1980646 , 7039.50748672, ..., 1916.29008386,
#        5011.83248721, 1890.25483129])

# %%
LR.score(X_train, y_train)   # R^2 score of the model on the training set
# Out:
# 0.9980574988739739

# %%
LR.score(X_test, y_test)   # R^2 score of the model on the TEST set
# Out:
# 0.9702114747635675

# %%
LR.coef_  # Model Coiefficients / parameters of the model
# Out:
# array([ 4.99222201e-03,  2.23918858e+00,  2.10856158e+01,  1.58166408e+01,
#         8.25068376e-02, -7.06788652e-02,  5.21063638e-02, -2.42189208e-03,
#        -2.25759258e-02, -6.88786270e-03,  1.58753943e-02,  1.72352175e-01,
#         7.60218558e-01,  4.74376341e+02, -1.34755630e+02,  1.15559280e+01,
#        -1.26786084e+01,  6.95973208e+01,  6.62809896e+01,  5.52359037e+01,
#        -1.69755760e+02,  8.87227192e+01, -3.76462994e+01,  2.66536665e+02,
#        -1.36460350e+02,  2.91442926e+02,  1.45085813e+02, -5.58967023e+01,
#         1.32313059e+01,  5.43029228e+01, -1.17191367e+02, -2.85439550e+02,
#        -7.15245638e+01,  8.52737696e+01, -1.05059368e+02,  1.68154865e+01,
#        -1.15614558e+02, -3.34627337e+01,  1.88862641e+02, -9.99805712e+01,
#        -2.21416526e+02, -2.43724576e+01,  9.52031466e+01,  2.14796802e+01,
#         1.69731653e+00,  3.56453440e+02, -4.17768228e+01, -4.07619931e+01,
#        -1.23984112e+02,  1.08144067e+02, -2.58443812e+01, -8.22996859e+01])

# %%
LR.intercept_  # the final intercept term
# Out:
# -108.16271925706042

# %%
# Set the display option
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
model_coef = pd.DataFrame(LR.coef_, index=X_new.columns, columns=['Model Coefficients'])
model_coef
# Out:
#                                 Model Coefficients
# vintage                                       0.00
# age                                           2.24
# gender                                       21.09
# dependents                                   15.82
# current_balance                               0.08
# previous_month_end_balance                   -0.07
# average_monthly_balance_prevQ2                0.05
# current_month_credit                         -0.00
# previous_month_credit                        -0.02
# current_month_debit                          -0.01
# previous_month_debit                          0.02
# current_month_balance                         0.17
# previous_month_balance                        0.76
# churn                                       474.38
# occupation_company                         -134.76
# occupation_retired                           11.56
# occupation_salaried                         -12.68
# occupation_self_employed                     69.60
# occupation_student                           66.28
# city_15                                      55.24
# city_61                                    -169.76
# city_146                                     88.72
# city_318                                    -37.65
# city_334                                    266.54
# city_409                                   -136.46
# city_491                                    291.44
# city_531                                    145.09
# city_575                                    -55.90
# city_623                                     13.23
# city_630                                     54.30
# city_649                                   -117.19
# city_656                                   -285.44
# city_834                                    -71.52
# city_904                                     85.27
# city_905                                   -105.06
# city_1020                                    16.82
# city_1084                                  -115.61
# city_1096                                   -33.46
# city_1111                                   188.86
# city_1232                                   -99.98
# city_1494                                  -221.42
# city_1525                                   -24.37
# city_1589                                    95.20
# city_2001                                    21.48
# city_2002                                     1.70
# city_2012                                   356.45
# city_2013                                   -41.78
# city_2014                                   -40.76
# city_100000                                -123.98
# customer_nw_category_1                      108.14
# customer_nw_category_2                      -25.84
# customer_nw_category_3                      -82.30

# %% [markdown]
# # Step 5: Data Refinement
# Let's do scaling and see if there is any further improvement in the model

# %%
# Scaling
SC = StandardScaler()

X_train_std = SC.fit_transform(X_train)  # Standardized Training set
X_test_std = SC.transform(X_test) # Standardized Test set

# %%
LR_std = LinearRegression()  # "untrained" model
LR_std.fit(X_train_std, y_train)  # model is trained now  on the standardized dataset
# Out:
# LinearRegression()

# %%
LR_std.score(X_train_std, y_train)    # R^2 score of the model on the standardized training set
# Out:
# 0.9980574549012659

# %%
LR_std.score(X_test_std, y_test)  # R^2 score of the model on the standardized test set
# Out:
# 0.9702217632643674

# %%
# Concl: There is no change for Linear REgression model. (which is as expected)
